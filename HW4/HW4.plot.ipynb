# %%
import numpy as np 
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import pandas as pd 
from time import sleep

import warnings
warnings.filterwarnings('ignore')

# %%
PI_VI = pd.read_csv("./PI_VI.csv", sep=",")

# %%
PI_VI.head(5)
# Out:
#    iter   PI_time  PI_reward  PI_steps  PI_convergence   VI_time  VI_reward  \
# 0     1  0.005777    -199.00    200.00       79.800000  0.002570     -199.0
# 1     2  0.013219    -199.00    200.00       50.398526  0.004147     -199.0
# 2     3  0.020106    -199.00    200.00       44.605914  0.005772     -199.0
# 3     4  0.026864    -154.42    183.70       50.779432  0.007973     -199.0
# 4     5  0.033393    -110.28    159.76       52.214501  0.009333     -199.0
#
#    VI_steps  VI_convergence
# 0     200.0       79.800000
# 1     200.0       49.004683
# 2     200.0       29.691186
# 3     200.0       27.991225
# 4     200.0       24.035250

# %%
# Create some mock data
plt.figure(figsize=(20,10))
#fig, ax1 = plt.subplots()
color = 'tab:red'
plt.xlabel('Iterations', fontsize=18)
plt.ylabel('Time(ms)', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.plot(PI_VI['iter'], PI_VI['PI_time']*1000, color='black')
plt.plot(PI_VI['iter'], PI_VI['VI_time']*1000, color='red')
plt.legend(fontsize=18)
#ax1.tick_params(axis='y', labelcolor=color)
#fig.tight_layout()  # otherwise the right y-label is slightly clipped

plt.show()

# %%
# Create some mock data
plt.figure(figsize=(20,10))
#fig, ax1 = plt.subplots()
color = 'tab:red'
plt.xlabel('Iterations', fontsize=18)
plt.ylabel('Rewards', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.plot(PI_VI['iter'], PI_VI['PI_reward'], color='black')
plt.plot(PI_VI['iter'], PI_VI['VI_reward'], color='red')
plt.legend(fontsize=18)
#ax1.tick_params(axis='y', labelcolor=color)
#fig.tight_layout()  # otherwise the right y-label is slightly clipped

plt.show()

# %%
# Create some mock data
plt.figure(figsize=(20,10))
#fig, ax1 = plt.subplots()

plt.xlabel('Iterations', fontsize=18)
plt.ylabel('Steps', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.plot(PI_VI['iter'], PI_VI['PI_steps'], color='black')
plt.plot(PI_VI['iter'], PI_VI['VI_steps'], color='red')
plt.legend(fontsize=18)
#ax1.tick_params(axis='y', labelcolor=color)
#fig.tight_layout()  # otherwise the right y-label is slightly clipped

plt.show()

# %%
# Create some mock data
plt.figure(figsize=(20,10))
#fig, ax1 = plt.subplots()

plt.xlabel('Steps', fontsize=18)
plt.ylabel('Convergence', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.plot(PI_VI['iter'], PI_VI['PI_convergence'], color='black')
plt.plot(PI_VI['iter'], PI_VI['VI_convergence'], color='red')
plt.legend(fontsize=18)
#ax1.tick_params(axis='y', labelcolor=color)
#fig.tight_layout()  # otherwise the right y-label is slightly clipped

plt.show()

# %%
LR01 = pd.read_csv("./LR0.1.csv", sep=",")

# %%
LR01.head(10)
# Out:
#    iter  LR0.1_E0.0_Time  LR0.1_E0.0_Rewards  LR0.1_E0.0_Steps  \
# 0     1         0.002174              -199.0             200.0
# 1     2         0.003238              -199.0             200.0
# 2     3         0.003973              -199.0             200.0
# 3     4         0.004708              -199.0             200.0
# 4     5         0.005441              -199.0             200.0
# 5     6         0.006135              -199.0             200.0
# 6     7         0.006821              -199.0             200.0
# 7     8         0.007496              -199.0             200.0
# 8     9         0.007981              -199.0             200.0
# 9    10         0.008663              -199.0             200.0
#
#    LR0.1_E0.0_Convergence  LR0.1_E0.5_Time  LR0.1_E0.5_Rewards  \
# 0               89.125908         0.000644              -199.0
# 1               79.253817         0.001357              -199.0
# 2               69.382295         0.002022              -199.0
# ...

# %%
# Create some mock data
plt.figure(figsize=(20,10))
#fig, ax1 = plt.subplots()
plt.xlabel('Iterations', fontsize=18)
plt.ylabel('Time(ms)', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.plot(LR01['iter'], LR01['LR0.1_E0.0_Time']*1000, color='black', lw=1)
plt.plot(LR01['iter'], LR01['LR0.1_E0.5_Time']*1000, color='red', lw=1)
plt.plot(LR01['iter'], LR01['LR0.1_E0.7_Time']*1000, color='green', lw=1)
plt.plot(LR01['iter'], LR01['LR0.1_E0.9_Time']*1000, color='blue', lw=1)
plt.legend(fontsize=18)
#ax1.tick_params(axis='y', labelcolor=color)
#fig.tight_layout()  # otherwise the right y-label is slightly clipped

plt.show()

# %%
# Create some mock data
plt.figure(figsize=(20,10))
#fig, ax1 = plt.subplots()
plt.xlabel('Iterations', fontsize=18)
plt.ylabel('Rewards', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.plot(LR01['iter'], LR01['LR0.1_E0.0_Rewards'], color='black', lw=0.5)
plt.plot(LR01['iter'], LR01['LR0.1_E0.5_Rewards'], color='red', lw=0.5)
plt.plot(LR01['iter'], LR01['LR0.1_E0.7_Rewards'], color='green', lw=0.5)
plt.plot(LR01['iter'], LR01['LR0.1_E0.9_Rewards'], color='blue', lw=0.5)
plt.legend(fontsize=18)
#ax1.tick_params(axis='y', labelcolor=color)
#fig.tight_layout()  # otherwise the right y-label is slightly clipped

plt.show()

# %%
# Create some mock data
plt.figure(figsize=(20,10))
#fig, ax1 = plt.subplots()
plt.xlabel('Iterations', fontsize=18)
plt.ylabel('Steps', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.plot(LR01['iter'], LR01['LR0.1_E0.0_Steps'], color='black', lw=0.5)
plt.plot(LR01['iter'], LR01['LR0.1_E0.5_Steps'], color='red', lw=0.5)
plt.plot(LR01['iter'], LR01['LR0.1_E0.7_Steps'], color='green', lw=0.5)
plt.plot(LR01['iter'], LR01['LR0.1_E0.9_Steps'], color='blue', lw=0.5)
plt.legend(fontsize=18)
#ax1.tick_params(axis='y', labelcolor=color)
#fig.tight_layout()  # otherwise the right y-label is slightly clipped

plt.show()

# %%
# Create some mock data
plt.figure(figsize=(20,10))
#fig, ax1 = plt.subplots()
plt.xlabel('Iterations', fontsize=18)
plt.ylabel('Convergence', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.plot(LR01['iter'], LR01['LR0.1_E0.0_Convergence'], color='black', lw=2)
plt.plot(LR01['iter'], LR01['LR0.1_E0.5_Convergence'], color='red', lw=2)
plt.plot(LR01['iter'], LR01['LR0.1_E0.7_Convergence'], color='green', lw=2)
plt.plot(LR01['iter'], LR01['LR0.1_E0.9_Convergence'], color='blue', lw=2)
plt.legend(fontsize=18)
#ax1.tick_params(axis='y', labelcolor=color)
#fig.tight_layout()  # otherwise the right y-label is slightly clipped

plt.show()

# %%
LR09 = pd.read_csv("./LR0.9.csv", sep=",")
# Create some mock data
plt.figure(figsize=(20,10))
#fig, ax1 = plt.subplots()
plt.xlabel('Iterations', fontsize=18)
plt.ylabel('Time(ms)', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.plot(LR09['iter'], LR09['LR0.9_E0.0_Time']*1000, color='black', lw=1)
plt.plot(LR09['iter'], LR09['LR0.9_E0.5_Time']*1000, color='red', lw=1)
plt.plot(LR09['iter'], LR09['LR0.9_E0.7_Time']*1000, color='green', lw=1)
plt.plot(LR09['iter'], LR09['LR0.9_E0.9_Time']*1000, color='blue', lw=1)
plt.legend(fontsize=18)
#ax1.tick_params(axis='y', labelcolor=color)
#fig.tight_layout()  # otherwise the right y-label is slightly clipped

plt.show()


# Create some mock data
plt.figure(figsize=(20,10))
#fig, ax1 = plt.subplots()
plt.xlabel('Iterations', fontsize=18)
plt.ylabel('Rewards', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.ylim(-300, 100)
plt.plot(LR09['iter'], LR09['LR0.9_E0.0_Rewards'], color='black', lw=0.5)
plt.plot(LR09['iter'], LR09['LR0.9_E0.5_Rewards'], color='red', lw=0.5)
plt.plot(LR09['iter'], LR09['LR0.9_E0.7_Rewards'], color='green', lw=0.5)
plt.plot(LR09['iter'], LR09['LR0.9_E0.9_Rewards'], color='blue', lw=0.5)
plt.legend(fontsize=18)
#ax1.tick_params(axis='y', labelcolor=color)
#fig.tight_layout()  # otherwise the right y-label is slightly clipped

plt.show()

# Create some mock data
plt.figure(figsize=(20,10))
#fig, ax1 = plt.subplots()
plt.xlabel('Iterations', fontsize=18)
plt.ylabel('Steps', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.ylim(20, 270)
plt.plot(LR09['iter'], LR09['LR0.9_E0.0_Steps'], color='black', lw=0.5)
plt.plot(LR09['iter'], LR09['LR0.9_E0.5_Steps'], color='red', lw=0.5)
plt.plot(LR09['iter'], LR09['LR0.9_E0.7_Steps'], color='green', lw=0.5)
plt.plot(LR09['iter'], LR09['LR0.9_E0.9_Steps'], color='blue', lw=0.5)
plt.legend(fontsize=18)
#ax1.tick_params(axis='y', labelcolor=color)
#fig.tight_layout()  # otherwise the right y-label is slightly clipped

plt.show()

# Create some mock data
plt.figure(figsize=(20,10))
#fig, ax1 = plt.subplots()
plt.xlabel('Iterations', fontsize=18)
plt.ylabel('Convergence', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.plot(LR09['iter'], LR09['LR0.9_E0.0_Convergence'], color='black', lw=2)
plt.plot(LR09['iter'], LR09['LR0.9_E0.5_Convergence'], color='red', lw=2)
plt.plot(LR09['iter'], LR09['LR0.9_E0.7_Convergence'], color='green', lw=2)
plt.plot(LR09['iter'], LR09['LR0.9_E0.9_Convergence'], color='blue', lw=2)
plt.legend(fontsize=18)
#ax1.tick_params(axis='y', labelcolor=color)
#fig.tight_layout()  # otherwise the right y-label is slightly clipped

plt.show()

# %%
CW = pd.read_csv("./cw.csv", sep=",")
# Create some mock data
plt.figure(figsize=(20,10))
#fig, ax1 = plt.subplots()
plt.xlabel('Iterations', fontsize=18)
plt.ylabel('Time(ms)', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlim(-100,1000)
plt.plot(CW['iter'], CW['E0.1_Time']*1000, color='black', lw=1)
plt.plot(CW['iter'], CW['E0.5_Time']*1000, color='red', lw=1)
plt.plot(CW['iter'], CW['E0.3_Time']*1000, color='green', lw=1)
plt.legend(fontsize=18)
#ax1.tick_params(axis='y', labelcolor=color)
#fig.tight_layout()  # otherwise the right y-label is slightly clipped

plt.show()


# Create some mock data
plt.figure(figsize=(20,10))
#fig, ax1 = plt.subplots()
plt.xlabel('Iterations', fontsize=18)
plt.ylabel('Rewards', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlim(-100,1000)
#plt.ylim(-300, 100)
plt.plot(CW['iter'], CW['E0.1_Rewards'], color='black', lw=0.5)
plt.plot(CW['iter'], CW['E0.5_Rewards'], color='red', lw=0.5)
plt.plot(CW['iter'], CW['E0.3_Rewards'], color='green', lw=0.5)
plt.legend(fontsize=18)
#ax1.tick_params(axis='y', labelcolor=color)
#fig.tight_layout()  # otherwise the right y-label is slightly clipped

plt.show()

# Create some mock data
plt.figure(figsize=(20,10))
#fig, ax1 = plt.subplots()
plt.xlabel('Iterations', fontsize=18)
plt.ylabel('Steps', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlim(-100,1000)
#plt.ylim(20, 270)
plt.plot(CW['iter'], CW['E0.1_Steps'], color='black', lw=0.5)
plt.plot(CW['iter'], CW['E0.5_Steps'], color='red', lw=0.5)
plt.plot(CW['iter'], CW['E0.3_Steps'], color='green', lw=0.5)
plt.legend(fontsize=18)
#ax1.tick_params(axis='y', labelcolor=color)
#fig.tight_layout()  # otherwise the right y-label is slightly clipped

plt.show()

# Create some mock data
plt.figure(figsize=(20,10))
#fig, ax1 = plt.subplots()
plt.xlabel('Iterations', fontsize=18)
plt.ylabel('Convergence', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlim(-100,1000)
plt.plot(CW['iter'], CW['E0.1_Convergence'], color='black', lw=2)
plt.plot(CW['iter'], CW['E0.5_Convergence'], color='red', lw=2)
plt.plot(CW['iter'], CW['E0.3_Convergence'], color='green', lw=2)
plt.legend(fontsize=18)
#ax1.tick_params(axis='y', labelcolor=color)
#fig.tight_layout()  # otherwise the right y-label is slightly clipped

plt.show()
